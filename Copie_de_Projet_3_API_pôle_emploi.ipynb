# %%
from offres_emploi import Api
from offres_emploi.utils import dt_to_str_iso
import datetime
import pandas as pd

pd.set_option("display.max_columns", None)

# %%
# Fonction pour effectuer une recherche avec gestion d'erreurs
def perform_search(api_client, params):
    try:
        # Initialisation des variables
        results = []
        start_range = 0
        max_results = float('inf')  # Initialisé à l'infini pour entrer dans la boucle

        # Pagination pour récupérer tous les résultats
        while start_range < max_results:
            params['range'] = f"{start_range}-{start_range + 149}"  # Utilisation de la pagination

            # Effectuer la recherche
            search_result = api_client.search(params=params)
            content_range = search_result.get('Content-Range', {})
            max_results_str = content_range.get('max_results', '0')
            max_results = int(max_results_str)

            # Ajouter les résultats actuels à la liste globale
            results.extend(search_result.get('resultats', []))

            # Mettre à jour la plage de départ pour la prochaine itération
            start_range += 150

        if max_results > 0:
            df_emploi = pd.DataFrame(results)
            return df_emploi
        else:
            print("Aucune offre d'emploi trouvée.")
            return pd.DataFrame()
    except Exception as e:
        print(f"Une erreur s'est produite lors de la recherche : {e}")
        return pd.DataFrame()

# Configuration du client API
client = Api(client_id="PAR_datajobs_addbc0bc41d7d51f05b218a78c5a95e14be4d73d536fde31c5962de09420f7ba",
             client_secret="ec561083589b4912fb4feebf33ef1078098c0b8b3f8ff04a665d3e46173f11e1")

# Exemple de recherche plus complexe
start_dt = datetime.datetime(2023, 9, 1, 12, 30)
end_dt = datetime.datetime.today()
params = {
    "motsCles": "data analyst",
    'minCreationDate': dt_to_str_iso(start_dt),
    'maxCreationDate': dt_to_str_iso(end_dt)
}

# Appel de la fonction de recherche avec gestion des erreurs
df_emploi_result = perform_search(client, params)

# Assurez-vous que les colonnes de date sont au format datetime
df_emploi_result['dateActualisation'] = pd.to_datetime(df_emploi_result['dateActualisation'])
df_emploi_result['dateCreation'] = pd.to_datetime(df_emploi_result['dateCreation'])

# %%
df_emploi_result
# Out:
#           id                                           intitule  \
# 0    166MBJK                                       Data analyst
# 1    166LRMP                                 Data Analyst (H/F)
# 2    166LJPL                    Data Analyst expérimenté  (H/F)
# 3    166KMJK                        DATA BUSINESS ANALYST (H/F)
# 4    166KBFG                                 Data Analyst (H/F)
# ..       ...                                                ...
# 273  7934666      Responsable équipe Risk Analytics (F/H) (H/F)
# 274  7416504           Analyste Qualité des Données (F/H) (H/F)
# 275  6791452                                    TECH LEAD (H/F)
# 276  6734474                                  Analyste BI (H/F)
# 277  6020314  Analyste / Yield Manager F/H - Siège Camping P...
#
#                                            description  \
# 0    Vous aussi, vous pensez que tout est mesurable...
# 1    Nous recherchons pour notre client spécialisé ...
# 2    Chez K-LAGAN, nous parions sur vous !\n\nVous ...
# 3    Vous êtes un(e) Data Business Analyst confirmé...
# 4    Nous recherchons pour notre client spécialisé ...
# ..                                                 ...
# 273  Nous recherchons un(e) :\n\n \n\nData Analyste...
# 274  Poste et missions\n\nVous serez rattaché.e à l...
# 275  Dans ce contexte, nous vous proposons l'opport...
# 276  RESPONSABILITÉS : \n\nVos missions ?\nIntégré ...
# 277  En tant que Analyste / Yield Manager vos missi...
#
#                  dateCreation         dateActualisation  \
# 0   2023-12-18 14:45:32+00:00 2023-12-19 10:59:04+00:00
# 1   2023-12-18 11:36:50+00:00 2023-12-19 14:15:00+00:00
# 2   2023-12-18 09:54:33+00:00 2023-12-19 11:17:58+00:00
# 3   2023-12-15 15:42:50+00:00 2023-12-18 09:15:02+00:00
# 4   2023-12-15 11:34:43+00:00 2023-12-19 13:34:30+00:00
# ..                        ...                       ...
# 273 2023-12-13 18:24:03+00:00 2023-12-13 18:24:03+00:00
# 274 2023-12-06 18:55:20+00:00 2023-12-06 18:55:20+00:00
# 275 2023-11-27 15:33:18+00:00 2023-11-27 15:33:18+00:00
# 276 2023-11-26 02:43:00+00:00 2023-11-26 02:43:00+00:00
# 277 2023-11-15 15:57:54+00:00 2023-11-15 15:57:54+00:00
#
#                                            lieuTravail romeCode  \
# 0    {'libelle': '92 - COURBEVOIE', 'latitude': 48....    M1403
# 1    {'libelle': '92 - BAGNEUX', 'latitude': 48.797...    M1403
# 2                         {'libelle': 'Ile-de-France'}    M1403
# 3    {'libelle': '38 - GRENOBLE', 'latitude': 45.18...    M1403
# 4    {'libelle': '92 - NANTERRE', 'latitude': 48.89...    M1403
# ..                                                 ...      ...
# 273  {'libelle': '91 - MASSY', 'latitude': 48.72779...    M1403
# 274  {'libelle': '75 - PARIS 13', 'latitude': 48.85...    M1403
# 275  {'libelle': '91 - MASSY', 'latitude': 48.72779...    M1403
# 276  {'libelle': '42 - ST ETIENNE', 'latitude': 45....    M1403
# 277              {'libelle': '75', 'commune': '75056'}    M1403
#
#                                   romeLibelle appellationlibelle  \
# 0    Études et prospectives socio-économiques       Data analyst
# 1    Études et prospectives socio-économiques       Data analyst
# 2    Études et prospectives socio-économiques       Data analyst
# 3    Études et prospectives socio-économiques       Data analyst
# 4    Études et prospectives socio-économiques       Data analyst
# ..                                        ...                ...
# 273  Études et prospectives socio-économiques       Data analyst
# 274  Études et prospectives socio-économiques       Data analyst
# 275  Études et prospectives socio-économiques       Data analyst
# 276  Études et prospectives socio-économiques       Data analyst
# 277  Études et prospectives socio-économiques       Data analyst
#
#                                             entreprise typeContrat  \
# 0        {'nom': 'OTCHEE', 'entrepriseAdaptee': False}         CDI
# 1                         {'entrepriseAdaptee': False}         CDI
# 2    {'nom': 'SAS K-LAGAN FRANCE', 'entrepriseAdapt...         CDI
# 3    {'nom': 'HARDIS GROUPE', 'description': '"Hard...         CDI
# 4                         {'entrepriseAdaptee': False}         CDI
# ..                                                 ...         ...
# 273  {'description': 'Carrefour Assurance a pour vo...         CDI
# 274  {'nom': 'BPCE SEF', 'description': 'BPCE Finan...         CDI
# 275  {'description': 'Nous rejoindre, c'est rejoind...         CDI
# 276  {'nom': 'Amiltone', 'description': 'Qui sommes...         CDI
# 277  {'nom': 'Siège Camping Paradis', 'description'...         CDI
#
#                typeContratLibelle    natureContrat experienceExige  \
# 0    Contrat à durée indéterminée  Contrat travail               E
# 1    Contrat à durée indéterminée  Contrat travail               E
# 2    Contrat à durée indéterminée  Contrat travail               E
# 3    Contrat à durée indéterminée  Contrat travail               E
# 4    Contrat à durée indéterminée  Contrat travail               E
# ..                            ...              ...             ...
# 273  Contrat à durée indéterminée  Contrat travail               S
# 274  Contrat à durée indéterminée  Contrat travail               D
# 275  Contrat à durée indéterminée  Contrat travail               E
# 276  Contrat à durée indéterminée  Contrat travail               E
# 277  Contrat à durée indéterminée  Contrat travail               E
#
#                    experienceLibelle  \
# 0                              2 ans
# 1                              2 ans
# 2                              5 ans
# 3                              5 ans
# 4                              2 ans
# ..                               ...
# 273  Expérience souhaitée de 2 An(s)
# 274                 Débutant accepté
# 275     Expérience exigée de 1 An(s)
# 276                Expérience exigée
# 277     Expérience exigée de 2 An(s)
#
#                                             formations  \
# 0    [{'codeFormation': '31054', 'domaineLibelle': ...
# 1    [{'niveauLibelle': 'Bac+2 ou équivalents', 'ex...
# 2                                                  NaN
# 3    [{'niveauLibelle': 'Bac+5 et plus ou équivalen...
# 4    [{'niveauLibelle': 'Bac+2 ou équivalents', 'ex...
# ..                                                 ...
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
#
#                                         langues  \
# 0     [{'libelle': 'Anglais', 'exigence': 'S'}]
# 1                                           NaN
# 2    [{'libelle': 'Espagnol', 'exigence': 'S'}]
# 3     [{'libelle': 'Anglais', 'exigence': 'S'}]
# 4                                           NaN
# ..                                          ...
# 273                                         NaN
# 274  [{'libelle': 'Français', 'exigence': 'E'}]
# 275                                         NaN
# 276                                         NaN
# 277                                         NaN
#
#                                            competences  \
# 0    [{'code': '109527', 'libelle': 'Adapter les ou...
# 1    [{'code': '109527', 'libelle': 'Adapter les ou...
# 2    [{'code': '100113', 'libelle': 'Logiciels de g...
# 3    [{'code': '109527', 'libelle': 'Adapter les ou...
# 4    [{'code': '109527', 'libelle': 'Adapter les ou...
# ..                                                 ...
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
#
#                                                salaire  \
# 0    {'libelle': 'Annuel de 35000,00 Euros sur 12 m...
# 1    {'libelle': 'Mensuel de 2500,00 Euros sur 12 m...
# 2    {'libelle': 'Annuel de 42000,00 Euros à 52000,...
# 3    {'commentaire': 'à négocier', 'complement1': '...
# 4    {'libelle': 'Mensuel de 2500,00 Euros sur 12 m...
# ..                                                 ...
# 273                                                 {}
# 274                                                 {}
# 275                                                 {}
# 276  {'libelle': 'Annuel de 30000,00 Euros à 45000,...
# 277                                                 {}
#
#           dureeTravailLibelle dureeTravailLibelleConverti  alternance  \
# 0      35H Travail en journée                 Temps plein       False
# 1      35H Travail en journée                 Temps plein       False
# 2    38H30 Travail en journée                 Temps plein       False
# 3    37H30 Travail en journée                 Temps plein       False
# 4      35H Travail en journée                 Temps plein       False
# ..                        ...                         ...         ...
# 273                       NaN                         NaN       False
# 274                       NaN                         NaN       False
# 275                       NaN                         NaN       False
# 276  35 H  Travail en journée                 Temps plein       False
# 277                       NaN                         NaN       False
#
#                                                contact  nombrePostes  \
# 0    {'nom': 'OTCHEE - Mme Alexandra DELEDICQ', 'co...             1
# 1                                                   {}             1
# 2                                                   {}             1
# 3    {'nom': 'HARDIS GROUPE - Mme Delphine CORREARD...             1
# 4                                                   {}             1
# ..                                                 ...           ...
# 273                                                NaN             1
# 274                                                NaN             1
# 275                                                NaN             1
# 276                                                NaN             1
# 277                                                NaN             1
#
#      accessibleTH deplacementCode         deplacementLibelle  \
# 0           False               3   Fréquents Zone régionale
# 1           False               1                     Jamais
# 2           False               4  Quotidiens Zone régionale
# 3           False               1                     Jamais
# 4           False               1                     Jamais
# ..            ...             ...                        ...
# 273         False             NaN                        NaN
# 274         False             NaN                        NaN
# 275         False             NaN                        NaN
# 276         False             NaN                        NaN
# 277         False             NaN                        NaN
#
#     qualificationCode qualificationLibelle codeNAF secteurActivite  \
# 0                   9                Cadre  62.02A              62
# 1                   8    Agent de maîtrise  78.10Z              78
# 2                   9                Cadre  71.12B              71
# 3                   9                Cadre  62.01Z              62
# 4                   8    Agent de maîtrise  78.10Z              78
# ..                ...                  ...     ...             ...
# 273               NaN                  NaN  65.12Z              65
# 274               NaN                  NaN     NaN             NaN
# 275               NaN                  NaN  62.09Z              62
# 276                 9                Cadre     NaN             NaN
# 277               NaN                  NaN  79.90Z              79
#
#                                 secteurActiviteLibelle  \
# 0       Conseil en systèmes et logiciels informatiques
# 1    Activités des agences de placement de main-d'œ...
# 2                        Ingénierie, études techniques
# 3                           Programmation informatique
# 4    Activités des agences de placement de main-d'œ...
# ..                                                 ...
# 273                                  Autres assurances
# 274                                                NaN
# 275                     Autres activités informatiques
# 276                                                NaN
# 277  Autres services de réservation et activités co...
#
#                               qualitesProfessionnelles  \
# 0    [{'libelle': 'Travailler en équipe', 'descript...
# 1    [{'libelle': 'Prendre des initiatives et être ...
# 2    [{'libelle': 'Prendre des initiatives et être ...
# 3    [{'libelle': 'Prendre des initiatives et être ...
# 4    [{'libelle': 'Prendre des initiatives et être ...
# ..                                                 ...
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
#
#                                           origineOffre offresManqueCandidats  \
# 0    {'origine': '1', 'urlOrigine': 'https://candid...                 False
# 1    {'origine': '1', 'urlOrigine': 'https://candid...                 False
# 2    {'origine': '1', 'urlOrigine': 'https://candid...                 False
# 3    {'origine': '1', 'urlOrigine': 'https://candid...                 False
# 4    {'origine': '1', 'urlOrigine': 'https://candid...                 False
# ..                                                 ...                   ...
# 273  {'origine': '2', 'urlOrigine': 'https://candid...                   NaN
# 274  {'origine': '2', 'urlOrigine': 'https://candid...                   NaN
# 275  {'origine': '2', 'urlOrigine': 'https://candid...                   NaN
# 276  {'origine': '2', 'urlOrigine': 'https://candid...                   NaN
# 277  {'origine': '2', 'urlOrigine': 'https://candid...                   NaN
#
#     experienceCommentaire permis complementExercice
# 0                     NaN    NaN                NaN
# 1                     NaN    NaN                NaN
# 2                     NaN    NaN                NaN
# 3                     NaN    NaN                NaN
# 4                     NaN    NaN                NaN
# ..                    ...    ...                ...
# 273                   NaN    NaN                NaN
# 274                   NaN    NaN                NaN
# 275                   NaN    NaN                NaN
# 276                   NaN    NaN                NaN
# 277                   NaN    NaN                NaN
#
# [278 rows x 38 columns]

# %%
# Enregistrez le DataFrame dans un fichier CSV
df_emploi_result.to_csv("df_emploi_result.csv", index=False, encoding='utf-8', sep=';')
